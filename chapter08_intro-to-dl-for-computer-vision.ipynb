# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104202 (407.04 KB)
# Trainable params: 104202 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 15s 8ms/step - loss: 0.1633 - accuracy: 0.9492
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0444 - accuracy: 0.9867
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0312 - accuracy: 0.9902
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0242 - accuracy: 0.9926
# Epoch 5/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0180 - accuracy: 0.9942

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0264 - accuracy: 0.9920
# Test accuracy: 0.992

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712202 (2.72 MB)
# Trainable params: 712202 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
import gdown

gdown.download(id='18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd', output='dogs-vs-cats.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd
# From (redirected): https://drive.google.com/uc?id=18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd&confirm=t&uuid=1406e2ff-a883-4b8e-b851-ead6e92d760b
# To: /content/dogs-vs-cats.zip
# 100%|██████████| 852M/852M [00:06<00:00, 136MB/s]
# 'dogs-vs-cats.zip'

# %%
from google.colab import files
files.upload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-34db83fe79dc> in <cell line: 2>()
#       1 from google.colab import files
# ----> 2 files.upload(dogs-vs-cats.zip)
#
# NameError: name 'dogs' is not defined

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 398, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !unzip -qq dogs-vs-cats.zip

# %%
# !unzip -qq train.zip

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPoolin  (None, 9, 9, 256)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991041 (3.78 MB)
# Trainable params: 991041 (3.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 10s 100ms/step - loss: 0.7019 - accuracy: 0.5060 - val_loss: 0.6921 - val_accuracy: 0.5010
# Epoch 2/30
# 63/63 [==============================] - 5s 76ms/step - loss: 0.6906 - accuracy: 0.5430 - val_loss: 0.7281 - val_accuracy: 0.5000
# Epoch 3/30
# 63/63 [==============================] - 5s 83ms/step - loss: 0.6874 - accuracy: 0.5635 - val_loss: 0.6687 - val_accuracy: 0.6220
# Epoch 4/30
# 63/63 [==============================] - 7s 90ms/step - loss: 0.6569 - accuracy: 0.6125 - val_loss: 0.6469 - val_accuracy: 0.6190
# Epoch 5/30
# 63/63 [==============================] - 4s 58ms/step - loss: 0.6316 - accuracy: 0.6465 - val_loss: 0.6169 - val_accuracy: 0.6480
# Epoch 6/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.5819 - accuracy: 0.7025 - val_loss: 0.6461 - val_accuracy: 0.5980
# Epoch 7/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.5631 - accuracy: 0.7130 - val_loss: 0.5774 - val_accuracy: 0.6900
# Epoch 8/30
# 63/63 [==============================] - 5s 71ms/step - loss: 0.5184 - accuracy: 0.7525 - val_loss: 0.6297 - val_accuracy: 0.6690
# Epoch 9/30
# 63/63 [==============================] - 4s 58ms/step - loss: 0.4759 - accuracy: 0.7720 - val_loss: 0.5742 - val_accuracy: 0.7150
# Epoch 10/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.4316 - accuracy: 0.8080 - val_loss: 0.5823 - val_accuracy: 0.7070
# Epoch 11/30
# 63/63 [==============================] - 6s 91ms/step - loss: 0.3796 - accuracy: 0.8355 - val_loss: 0.7220 - val_accuracy: 0.6900
# Epoch 12/30
# 63/63 [==============================] - 5s 65ms/step - loss: 0.3200 - accuracy: 0.8685 - val_loss: 0.8576 - val_accuracy: 0.6850
# Epoch 13/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.2758 - accuracy: 0.8780 - val_loss: 0.7902 - val_accuracy: 0.7270
# Epoch 14/30
# 63/63 [==============================] - 5s 71ms/step - loss: 0.2146 - accuracy: 0.9110 - val_loss: 0.9729 - val_accuracy: 0.7130
# Epoch 15/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.1796 - accuracy: 0.9285 - val_loss: 0.9773 - val_accuracy: 0.7290
# Epoch 16/30
# 63/63 [==============================] - 4s 54ms/step - loss: 0.1275 - accuracy: 0.9530 - val_loss: 1.2972 - val_accuracy: 0.7080
# Epoch 17/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.1126 - accuracy: 0.9620 - val_loss: 1.0958 - val_accuracy: 0.7070
# Epoch 18/30
# 63/63 [==============================] - 7s 105ms/step - loss: 0.0779 - accuracy: 0.9760 - val_loss: 1.5725 - val_accuracy: 0.7070
# Epoch 19/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0868 - accuracy: 0.9745 - val_loss: 1.4705 - val_accuracy: 0.6980
# Epoch 20/30
# 63/63 [==============================] - 4s 59ms/step - loss: 0.0609 - accuracy: 0.9765 - val_loss: 1.7596 - val_accuracy: 0.7250
# Epoch 21/30
# 63/63 [==============================] - 6s 89ms/step - loss: 0.0805 - accuracy: 0.9725 - val_loss: 1.5055 - val_accuracy: 0.7110
# Epoch 22/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0421 - accuracy: 0.9870 - val_loss: 1.9181 - val_accuracy: 0.7260
# Epoch 23/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0739 - accuracy: 0.9780 - val_loss: 1.5897 - val_accuracy: 0.7350
# Epoch 24/30
# 63/63 [==============================] - 6s 91ms/step - loss: 0.0412 - accuracy: 0.9895 - val_loss: 1.6387 - val_accuracy: 0.7310
# Epoch 25/30
# 63/63 [==============================] - 4s 63ms/step - loss: 0.0327 - accuracy: 0.9890 - val_loss: 1.9952 - val_accuracy: 0.7320
# Epoch 26/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.0579 - accuracy: 0.9840 - val_loss: 1.8598 - val_accuracy: 0.7320
# Epoch 27/30
# 63/63 [==============================] - 7s 108ms/step - loss: 0.0589 - accuracy: 0.9885 - val_loss: 2.8912 - val_accuracy: 0.7170
# Epoch 28/30
# 63/63 [==============================] - 5s 77ms/step - loss: 0.0494 - accuracy: 0.9870 - val_loss: 2.0055 - val_accuracy: 0.7370
# Epoch 29/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.0501 - accuracy: 0.9875 - val_loss: 2.4153 - val_accuracy: 0.7090
# Epoch 30/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0554 - accuracy: 0.9835 - val_loss: 2.1874 - val_accuracy: 0.7330

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 2s 29ms/step - loss: 0.5485 - accuracy: 0.7335
# Test accuracy: 0.734

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 9s 95ms/step - loss: 0.6965 - accuracy: 0.4875 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 2/100
# 63/63 [==============================] - 5s 72ms/step - loss: 0.6937 - accuracy: 0.5225 - val_loss: 0.6911 - val_accuracy: 0.5020
# Epoch 3/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.6942 - accuracy: 0.5210 - val_loss: 0.6841 - val_accuracy: 0.6030
# Epoch 4/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.6740 - accuracy: 0.6025 - val_loss: 0.6485 - val_accuracy: 0.6250
# Epoch 5/100
# 63/63 [==============================] - 4s 63ms/step - loss: 0.6657 - accuracy: 0.6345 - val_loss: 0.6418 - val_accuracy: 0.6370
# Epoch 6/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.6455 - accuracy: 0.6435 - val_loss: 0.6765 - val_accuracy: 0.5930
# Epoch 7/100
# 63/63 [==============================] - 6s 87ms/step - loss: 0.6272 - accuracy: 0.6605 - val_loss: 0.6042 - val_accuracy: 0.6800
# Epoch 8/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.6108 - accuracy: 0.6650 - val_loss: 0.6292 - val_accuracy: 0.6450
# Epoch 9/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.5932 - accuracy: 0.6810 - val_loss: 0.5982 - val_accuracy: 0.6730
# Epoch 10/100
# 63/63 [==============================] - 7s 98ms/step - loss: 0.5912 - accuracy: 0.6725 - val_loss: 0.6270 - val_accuracy: 0.6360
# Epoch 11/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.5859 - accuracy: 0.7130 - val_loss: 0.5820 - val_accuracy: 0.6890
# Epoch 12/100
# 63/63 [==============================] - 4s 56ms/step - loss: 0.5738 - accuracy: 0.7025 - val_loss: 0.6146 - val_accuracy: 0.6600
# Epoch 13/100
# 63/63 [==============================] - 5s 78ms/step - loss: 0.5898 - accuracy: 0.7030 - val_loss: 0.5769 - val_accuracy: 0.6960
# Epoch 14/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.5538 - accuracy: 0.7295 - val_loss: 0.5581 - val_accuracy: 0.7240
# Epoch 15/100
# 63/63 [==============================] - 4s 57ms/step - loss: 0.5551 - accuracy: 0.7185 - val_loss: 0.6257 - val_accuracy: 0.6650
# Epoch 16/100
# 63/63 [==============================] - 4s 57ms/step - loss: 0.5414 - accuracy: 0.7350 - val_loss: 0.5603 - val_accuracy: 0.7050
# Epoch 17/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.5371 - accuracy: 0.7315 - val_loss: 0.5561 - val_accuracy: 0.7230
# Epoch 18/100
# 63/63 [==============================] - 4s 59ms/step - loss: 0.5452 - accuracy: 0.7300 - val_loss: 0.5335 - val_accuracy: 0.7210
# Epoch 19/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.5144 - accuracy: 0.7485 - val_loss: 0.6862 - val_accuracy: 0.6650
# Epoch 20/100
# 63/63 [==============================] - 6s 88ms/step - loss: 0.5073 - accuracy: 0.7485 - val_loss: 0.5096 - val_accuracy: 0.7460
# Epoch 21/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.4938 - accuracy: 0.7625 - val_loss: 0.6055 - val_accuracy: 0.7040
# Epoch 22/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.4930 - accuracy: 0.7680 - val_loss: 0.6186 - val_accuracy: 0.6990
# Epoch 23/100
# 63/63 [==============================] - 6s 94ms/step - loss: 0.4957 - accuracy: 0.7605 - val_loss: 0.4863 - val_accuracy: 0.7770
# Epoch 24/100
# 63/63 [==============================] - 4s 57ms/step - loss: 0.4911 - accuracy: 0.7620 - val_loss: 0.4942 - val_accuracy: 0.7720
# Epoch 25/100
# 63/63 [==============================] - 4s 62ms/step - loss: 0.4689 - accuracy: 0.7730 - val_loss: 0.4838 - val_accuracy: 0.7600
# Epoch 26/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0
100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.1794 - accuracy: 0.9405 - val_loss: 0.7441 - val_accuracy: 0.8270
# Epoch 99/100
# 63/63 [==============================] - 4s 58ms/step - loss: 0.1745 - accuracy: 0.9395 - val_loss: 0.6853 - val_accuracy: 0.8340
# Epoch 100/100
# 63/63 [==============================] - 7s 115ms/step - loss: 0.1530 - accuracy: 0.9370 - val_loss: 0.9778 - val_accuracy: 0.8170

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 2s 29ms/step - loss: 0.4692 - accuracy: 0.8080
# Test accuracy: 0.808

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
conv_base.summary()

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 12ms/step - loss: 16.6279 - accuracy: 0.9270 - val_loss: 4.3848 - val_accuracy: 0.9660
# Epoch 2/20
# 63/63 [==============================] - 0s 5ms/step - loss: 3.4685 - accuracy: 0.9715 - val_loss: 4.8264 - val_accuracy: 0.9660
# Epoch 3/20
# 63/63 [==============================] - 0s 5ms/step - loss: 3.4210 - accuracy: 0.9775 - val_loss: 5.0986 - val_accuracy: 0.9720
# Epoch 4/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.3692 - accuracy: 0.9880 - val_loss: 5.6082 - val_accuracy: 0.9680
# Epoch 5/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.8842 - accuracy: 0.9920 - val_loss: 5.2531 - val_accuracy: 0.9670
# Epoch 6/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7309 - accuracy: 0.9950 - val_loss: 6.3969 - val_accuracy: 0.9640
# Epoch 7/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.2693 - accuracy: 0.9970 - val_loss: 5.2959 - val_accuracy: 0.9710
# Epoch 8/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.3631 - accuracy: 0.9980 - val_loss: 4.2076 - val_accuracy: 0.9790
# Epoch 9/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.3858 - accuracy: 0.9970 - val_loss: 4.9122 - val_accuracy: 0.9770
# Epoch 10/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1626 - accuracy: 0.9965 - val_loss: 4.8171 - val_accuracy: 0.9740
# Epoch 11/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.9980 - val_loss: 4.5992 - val_accuracy: 0.9760
# Epoch 12/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3538 - accuracy: 0.9985 - val_loss: 4.9764 - val_accuracy: 0.9760
# Epoch 13/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.2483e-04 - accuracy: 1.0000 - val_loss: 5.5161 - val_accuracy: 0.9760
# Epoch 14/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5764 - accuracy: 0.9955 - val_loss: 5.6820 - val_accuracy: 0.9780
# Epoch 15/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1904 - accuracy: 0.9980 - val_loss: 6.1092 - val_accuracy: 0.9760
# Epoch 16/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2206 - accuracy: 0.9990 - val_loss: 5.6817 - val_accuracy: 0.9780
# Epoch 17/20
# 63/63 [==============================] - 0s 7ms/step - loss: 4.6396e-06 - accuracy: 1.0000 - val_loss: 4.7921 - val_accuracy: 0.9800
# Epoch 18/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0671 - accuracy: 0.9990 - val_loss: 5.2544 - val_accuracy: 0.9750
# Epoch 19/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0624 - accuracy: 0.9990 - val_loss: 6.8949 - val_accuracy: 0.9730
# Epoch 20/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5568 - accuracy: 0.9975 - val_loss: 8.4587 - val_accuracy: 0.9710

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset)
    #callbacks=callbacks)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 10s 155ms/step - loss: 7.8990 - accuracy: 0.9415 - val_loss: 5.6265 - val_accuracy: 0.9670
# Epoch 2/50
# 63/63 [==============================] - 10s 154ms/step - loss: 6.6014 - accuracy: 0.9540 - val_loss: 3.4022 - val_accuracy: 0.9750
# Epoch 3/50
# 63/63 [==============================] - 10s 155ms/step - loss: 5.8994 - accuracy: 0.9565 - val_loss: 4.7515 - val_accuracy: 0.9670
# Epoch 4/50
# 63/63 [==============================] - 12s 180ms/step - loss: 5.1814 - accuracy: 0.9630 - val_loss: 3.9003 - val_accuracy: 0.9760
# Epoch 5/50
# 48/63 [=====================>........] - ETA: 1s - loss: 4.4216 - accuracy: 0.9681
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-ab82ede23c28> in <cell line: 7>()
#       5         monitor="val_loss")
#       6 ]
# ----> 7 history = model.fit(
#       8     train_dataset,
#       9     epochs=50,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %% [markdown]
# ### Fine-tuning a pretrained model

# %%
conv_base.summary()

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset)
    #callbacks=callbacks)

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %% [markdown]
# ## Summary
